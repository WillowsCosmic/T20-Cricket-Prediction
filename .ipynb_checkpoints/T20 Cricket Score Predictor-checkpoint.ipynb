# %% [markdown]
# #  🏏 T20 Cricket Score Predictor

# %% [markdown]
# ### Overview
# A machine learning model that predicts the final T20 cricket score in real-time based on current match conditions and recent performance trends.
#
# ### How It Works
# The model analyzes the current match state and uses **XGBoost** (Gradient Boosting) to predict the final score by considering:
# - Current score, wickets, and balls remaining
# - Run rate trends (overall and last 5 overs)
# - Historical performance of teams at specific venues
# - Recent momentum (wickets and runs in last 5 overs)
#
# ### Key Features
# - **Real-time Predictions**: Get score forecasts at any point during an innings
# - **Context-Aware**: Accounts for venue, teams, and match situation
# - **Momentum Analysis**: Weights recent performance (last 5 overs) heavily
# - **High Accuracy**: Trained on extensive ball-by-ball historical data

# %% [markdown]
# ## 📊🔍Data Extraction

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("t20i_info.csv")

# %%
df.shape
# Out:
# (63888, 9)

# %%
df.head()
# Out:
#    Unnamed: 0  match_id batting_team bowling_team  ball  runs  \
# 0           0         2    Australia    Sri Lanka   0.1     0
# 1           1         2    Australia    Sri Lanka   0.2     0
# 2           2         2    Australia    Sri Lanka   0.3     1
# 3           3         2    Australia    Sri Lanka   0.4     2
# 4           4         2    Australia    Sri Lanka   0.5     0
#
#   player_dismissed city                     venue
# 0                0  NaN  Melbourne Cricket Ground
# 1                0  NaN  Melbourne Cricket Ground
# 2                0  NaN  Melbourne Cricket Ground
# 3                0  NaN  Melbourne Cricket Ground
# 4                0  NaN  Melbourne Cricket Ground

# %%
df.isnull().sum()
# Out:
# Unnamed: 0             0
# match_id               0
# batting_team           0
# bowling_team           0
# ball                   0
# runs                   0
# player_dismissed       0
# city                8548
# venue                  0
# dtype: int64

# %%
df.drop('city', axis=1, inplace=True)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# match_id            0
# batting_team        0
# bowling_team        0
# ball                0
# runs                0
# player_dismissed    0
# venue               0
# dtype: int64

# %%
print(df['venue'].value_counts())
eligible_venues = df['venue'].value_counts()[df['venue'].value_counts() >= 30].index.tolist()
df = df[df['venue'].isin(eligible_venues)]
# Out:
# venue
# Shere Bangla National Stadium          3420
# R Premadasa Stadium                    2983
# Dubai International Cricket Stadium    2969
# New Wanderers Stadium                  2819
# Eden Park                              2532
#                                        ...
# Senwes Park                             122
# Sardar Patel Stadium, Motera            121
# Hagley Oval                             121
# Subrata Roy Sahara Stadium              121
# Carrara Oval                             64
# Name: count, Length: 94, dtype: int64

# %%
df.shape
# Out:
# (63888, 8)

# %%
df.head()
# Out:
#    Unnamed: 0  match_id batting_team bowling_team  ball  runs  \
# 0           0         2    Australia    Sri Lanka   0.1     0
# 1           1         2    Australia    Sri Lanka   0.2     0
# 2           2         2    Australia    Sri Lanka   0.3     1
# 3           3         2    Australia    Sri Lanka   0.4     2
# 4           4         2    Australia    Sri Lanka   0.5     0
#
#   player_dismissed                     venue
# 0                0  Melbourne Cricket Ground
# 1                0  Melbourne Cricket Ground
# 2                0  Melbourne Cricket Ground
# 3                0  Melbourne Cricket Ground
# 4                0  Melbourne Cricket Ground

# %%
df['current_score'] = df.groupby('match_id')['runs'].cumsum()

# %%
df.head()
# Out:
#    Unnamed: 0  match_id batting_team bowling_team  ball  runs  \
# 0           0         2    Australia    Sri Lanka   0.1     0
# 1           1         2    Australia    Sri Lanka   0.2     0
# 2           2         2    Australia    Sri Lanka   0.3     1
# 3           3         2    Australia    Sri Lanka   0.4     2
# 4           4         2    Australia    Sri Lanka   0.5     0
#
#   player_dismissed                     venue  current_score
# 0                0  Melbourne Cricket Ground              0
# 1                0  Melbourne Cricket Ground              0
# 2                0  Melbourne Cricket Ground              1
# 3                0  Melbourne Cricket Ground              3
# 4                0  Melbourne Cricket Ground              3

# %%
df['over'] = df['ball'].apply(lambda x : str(x).split(".")[0])
df['ball_no'] = df['ball'].apply(lambda x : str(x).split(".")[1])

# %%
df.head()
# Out:
#    Unnamed: 0  match_id batting_team bowling_team  ball  runs  \
# 0           0         2    Australia    Sri Lanka   0.1     0
# 1           1         2    Australia    Sri Lanka   0.2     0
# 2           2         2    Australia    Sri Lanka   0.3     1
# 3           3         2    Australia    Sri Lanka   0.4     2
# 4           4         2    Australia    Sri Lanka   0.5     0
#
#   player_dismissed                     venue  current_score over ball_no
# 0                0  Melbourne Cricket Ground              0    0       1
# 1                0  Melbourne Cricket Ground              0    0       2
# 2                0  Melbourne Cricket Ground              1    0       3
# 3                0  Melbourne Cricket Ground              3    0       4
# 4                0  Melbourne Cricket Ground              3    0       5

# %%
df['ball_bowled'] = (df['over'].astype(int)*6 + df['ball_no'].astype(int))

# %%
df['balls_left'] = 120 - df['ball_bowled']

# %%
df.tail()
# Out:
#        Unnamed: 0  match_id batting_team bowling_team  ball  runs  \
# 63883         121       964    Sri Lanka    Australia  19.3     1
# 63884         122       964    Sri Lanka    Australia  19.4     0
# 63885         123       964    Sri Lanka    Australia  19.5     0
# 63886         124       964    Sri Lanka    Australia  19.6     2
# 63887         125       964    Sri Lanka    Australia  19.7     1
#
#       player_dismissed                venue  current_score over ball_no  \
# 63883                0  R Premadasa Stadium            125   19       3
# 63884                0  R Premadasa Stadium            125   19       4
# 63885      DM de Silva  R Premadasa Stadium            125   19       5
# 63886                0  R Premadasa Stadium            127   19       6
# 63887                0  R Premadasa Stadium            128   19       7
#
#        ball_bowled  balls_left
# 63883          117           3
# 63884          118           2
# 63885          119           1
# 63886          120           0
# 63887          121          -1

# %%
df['balls_left'] = df['balls_left'].apply(lambda x:0 if x<0 else x)

# %%
df.head()
# Out:
#    Unnamed: 0  match_id batting_team bowling_team  ball  runs  \
# 0           0         2    Australia    Sri Lanka   0.1     0
# 1           1         2    Australia    Sri Lanka   0.2     0
# 2           2         2    Australia    Sri Lanka   0.3     1
# 3           3         2    Australia    Sri Lanka   0.4     2
# 4           4         2    Australia    Sri Lanka   0.5     0
#
#   player_dismissed                     venue  current_score over ball_no  \
# 0                0  Melbourne Cricket Ground              0    0       1
# 1                0  Melbourne Cricket Ground              0    0       2
# 2                0  Melbourne Cricket Ground              1    0       3
# 3                0  Melbourne Cricket Ground              3    0       4
# 4                0  Melbourne Cricket Ground              3    0       5
#
#    ball_bowled  balls_left
# 0            1         119
# 1            2         118
# 2            3         117
# 3            4         116
# 4            5         115

# %%
df['player_dismissed'] = df['player_dismissed'].apply(lambda x:1 if x != '0' else '0')

# %%
df['player_dismissed'] = df['player_dismissed'].astype(int)

# %%
df.head()
# Out:
#    Unnamed: 0  match_id batting_team bowling_team  ball  runs  \
# 0           0         2    Australia    Sri Lanka   0.1     0
# 1           1         2    Australia    Sri Lanka   0.2     0
# 2           2         2    Australia    Sri Lanka   0.3     1
# 3           3         2    Australia    Sri Lanka   0.4     2
# 4           4         2    Australia    Sri Lanka   0.5     0
#
#    player_dismissed                     venue  current_score over ball_no  \
# 0                 0  Melbourne Cricket Ground              0    0       1
# 1                 0  Melbourne Cricket Ground              0    0       2
# 2                 0  Melbourne Cricket Ground              1    0       3
# 3                 0  Melbourne Cricket Ground              3    0       4
# 4                 0  Melbourne Cricket Ground              3    0       5
#
#    ball_bowled  balls_left
# 0            1         119
# 1            2         118
# 2            3         117
# 3            4         116
# 4            5         115

# %%
df['player_dismissed'] = df.groupby('match_id')['player_dismissed'].cumsum()

# %%
df['wicket_left'] = 10 - df['player_dismissed']

# %%
df['current_run_rate'] = (df['current_score']*6 / df['ball_bowled'])

# %%
df.tail()
# Out:
#        Unnamed: 0  match_id batting_team bowling_team  ball  runs  \
# 63883         121       964    Sri Lanka    Australia  19.3     1
# 63884         122       964    Sri Lanka    Australia  19.4     0
# 63885         123       964    Sri Lanka    Australia  19.5     0
# 63886         124       964    Sri Lanka    Australia  19.6     2
# 63887         125       964    Sri Lanka    Australia  19.7     1
#
#        player_dismissed                venue  current_score over ball_no  \
# 63883                 8  R Premadasa Stadium            125   19       3
# 63884                 8  R Premadasa Stadium            125   19       4
# 63885                 9  R Premadasa Stadium            125   19       5
# 63886                 9  R Premadasa Stadium            127   19       6
# 63887                 9  R Premadasa Stadium            128   19       7
#
#        ball_bowled  balls_left  wicket_left  current_run_rate
# 63883          117           3            2          6.410256
# 63884          118           2            2          6.355932
# 63885          119           1            1          6.302521
# 63886          120           0            1          6.350000
# 63887          121           0            1          6.347107

# %%
groups = df.groupby('match_id')

last_five = []

for match_id in df['match_id'].unique():
    # Calculate rolling sum of PREVIOUS 30 balls (not including current)
    rolling_sum = groups.get_group(match_id)['runs'].rolling(window=30).sum().shift(1).fillna(0)
    last_five.extend(rolling_sum.values.tolist())

df['last_five'] = last_five

# %%
final_df = df.groupby('match_id').sum()['runs'].reset_index().merge(df,on="match_id")

# %%
final_df
# Out:
#        match_id  runs_x  Unnamed: 0 batting_team bowling_team  ball  runs_y  \
# 0             2     168           0    Australia    Sri Lanka   0.1       0
# 1             2     168           1    Australia    Sri Lanka   0.2       0
# 2             2     168           2    Australia    Sri Lanka   0.3       1
# 3             2     168           3    Australia    Sri Lanka   0.4       2
# 4             2     168           4    Australia    Sri Lanka   0.5       0
# ...         ...     ...         ...          ...          ...   ...     ...
# 63883       964     128         121    Sri Lanka    Australia  19.3       1
# 63884       964     128         122    Sri Lanka    Australia  19.4       0
# 63885       964     128         123    Sri Lanka    Australia  19.5       0
# 63886       964     128         124    Sri Lanka    Australia  19.6       2
# 63887       964     128         125    Sri Lanka    Australia  19.7       1
#
#        player_dismissed                     venue  current_score over ball_no  \
# 0                     0  Melbourne Cricket Ground              0    0       1
# 1                     0  Melbourne Cricket Ground              0    0       2
# 2                     0  Melbourne Cricket Ground              1    0       3
# 3                     0  Melbourne Cricket Ground              3    0       4
# 4                     0  Melbourne Cricket Ground              3    0       5
# ...                 ...                       ...            ...  ...     ...
# 63883                 8       R Premadasa Stadium            125   19       3
# 63884                 8       R Premadasa Stadium            125   19       4
# 63885                 9       R Premadasa Stadium            125   19       5
# 63886                 9       R Premadasa Stadium            127   19       6
# 63887                 9       R Premadasa Stadium            128   19       7
#
#        ball_bowled  balls_left  wicket_left  current_run_rate  last_five
# 0                1         119           10          0.000000        0.0
# 1                2         118           10          0.000000        0.0
# 2                3         117           10          2.000000        0.0
# 3                4         116           10          4.500000        0.0
# 4                5         115           10          3.600000        0.0
# ...            ...         ...          ...               ...        ...
# 63883          117           3            2          6.410256       35.0
# 63884          118           2            2          6.355932       32.0
# 63885          119           1            1          6.302521       32.0
# 63886          120           0            1          6.350000       32.0
# 63887          121           0            1          6.347107       33.0
#
# [63888 rows x 17 columns]

# %%
final_df.columns
# Out:
# Index(['match_id', 'runs_x', 'Unnamed: 0', 'batting_team', 'bowling_team',
#        'ball', 'runs_y', 'player_dismissed', 'venue', 'current_score', 'over',
#        'ball_no', 'ball_bowled', 'balls_left', 'wicket_left',
#        'current_run_rate', 'last_five'],
#       dtype='object')

# %%
final_df = final_df[['batting_team', 'bowling_team','venue','balls_left', 'current_score',  'wicket_left',
       'current_run_rate', 'last_five','runs_x']]

# %%
final_df.dropna(inplace=True)
# Out:
# /tmp/ipykernel_9916/2709626079.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df.dropna(inplace=True)

# %%
final_df.isnull().sum()
# Out:
# batting_team        0
# bowling_team        0
# venue               0
# balls_left          0
# current_score       0
# wicket_left         0
# current_run_rate    0
# last_five           0
# runs_x              0
# dtype: int64

# %%
final_df.shape
# Out:
# (63888, 9)

# %% [markdown]
# ## 🧠📊Model Training

# %%
final_df.head()
# Out:
#   batting_team bowling_team                     venue  balls_left  \
# 0    Australia    Sri Lanka  Melbourne Cricket Ground         119
# 1    Australia    Sri Lanka  Melbourne Cricket Ground         118
# 2    Australia    Sri Lanka  Melbourne Cricket Ground         117
# 3    Australia    Sri Lanka  Melbourne Cricket Ground         116
# 4    Australia    Sri Lanka  Melbourne Cricket Ground         115
#
#    current_score  wicket_left  current_run_rate  last_five  runs_x
# 0              0           10               0.0        0.0     168
# 1              0           10               0.0        0.0     168
# 2              1           10               2.0        0.0     168
# 3              3           10               4.5        0.0     168
# 4              3           10               3.6        0.0     168

# %%
X = final_df.drop(columns=['runs_x'])
y = final_df['runs_x']

# %%
X
# Out:
#       batting_team bowling_team                     venue  balls_left  \
# 0        Australia    Sri Lanka  Melbourne Cricket Ground         119
# 1        Australia    Sri Lanka  Melbourne Cricket Ground         118
# 2        Australia    Sri Lanka  Melbourne Cricket Ground         117
# 3        Australia    Sri Lanka  Melbourne Cricket Ground         116
# 4        Australia    Sri Lanka  Melbourne Cricket Ground         115
# ...            ...          ...                       ...         ...
# 63883    Sri Lanka    Australia       R Premadasa Stadium           3
# 63884    Sri Lanka    Australia       R Premadasa Stadium           2
# 63885    Sri Lanka    Australia       R Premadasa Stadium           1
# 63886    Sri Lanka    Australia       R Premadasa Stadium           0
# 63887    Sri Lanka    Australia       R Premadasa Stadium           0
#
#        current_score  wicket_left  current_run_rate  last_five
# 0                  0           10          0.000000        0.0
# 1                  0           10          0.000000        0.0
# 2                  1           10          2.000000        0.0
# 3                  3           10          4.500000        0.0
# 4                  3           10          3.600000        0.0
# ...              ...          ...               ...        ...
# 63883            125            2          6.410256       35.0
# 63884            125            2          6.355932       32.0
# 63885            125            1          6.302521       32.0
# 63886            127            1          6.350000       32.0
# 63887            128            1          6.347107       33.0
#
# [63888 rows x 8 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.2)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.metrics import r2_score,mean_absolute_error

# %%
transformer = ColumnTransformer([
    ('trf', OneHotEncoder(sparse_output=False, drop='first'), ['batting_team', 'bowling_team', 'venue'])
], remainder='passthrough')

# %%
pipe = Pipeline(steps=[
    ('step1',transformer),
    ('step2',StandardScaler()),
    ('step3',XGBRegressor(n_estimators=1000,learning_rate=0.2,max_depth=12,random_state = 1)),  
])

# %%
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse_output=False),
#                                                   ['batting_team',
#                                                    'bowling_team',
#                                                    'venue'])])),
#                 ('step2', StandardScaler()),
#                 ('step3',
#                  XGBRegressor(base_score=None, booster=None, callbacks=None,
#                               colsample_bylevel=None, colsample_bynode=None,
#                               colsample_bytree=None, device=Non...
#                               feature_types=None, feature_weights=None,
#                               gamma=None, grow_policy=None,
#                               importance_type=None,
#                               interaction_constraints=None, learning_rate=0.2,
#                               max_bin=None, max_cat_threshold=None,
#                               max_cat_to_onehot=None, max_delta_step=None,
#                               max_depth=12, max_leaves=None,
#                               min_child_weight=None, missing=nan,
#                               monotone_constraints=None, multi_strategy=None,
#                               n_estimators=1000, n_jobs=None,
#                               num_parallel_tree=None, ...))])

# %%
y_pred = pipe.predict(X_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.9693306684494019

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 2.19028902053833

# %%
pipe.score(X_test,y_test)
# Out:
# 0.9693306684494019

# %%
import pickle
pickle.dump(pipe, open('pipe.pkl','wb'))
